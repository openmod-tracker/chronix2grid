# %% [markdown]
# ## This notebook will guide you through the use of the chronix2grid command line interface.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>WARNING</b>: If you run <b>chronix2grid in a virtual env</b>, make sure that you either:
#
#     - sourced your virtual env before launching jupyter: source v_env_chronix2grid/bin/activate
#
#     - created an ipython kernel for this virtual env, and that you are actually running this kernerl now
# </div>

# %%
import os

# %%
# !chronix2grid --help
# Out:
# Usage: chronix2grid [OPTIONS]
#
# Options:
#   --case TEXT               case folder to base generation on
#   --start-date TEXT         Start date to generate chronics
#   --weeks INTEGER           Number of weeks to generate
#   --by-n-weeks INTEGER      Size of the output chunks in weeks
#   --n_scenarios INTEGER     Number of scenarios to generate
#   --mode TEXT               Steps to execute : L(K) for loads only (and
#                             KPI);R(K) for renewables (and KPI) only; LRT (K)
#                             for load, renewable and thermic generation (and
#                             KPI); LRDT(TK) for load, renewable, loss
#                             (dissipation) generation (and thermic and KPI)
#   --input-folder TEXT       Directory to read input files from.
#   --output-folder TEXT      Directory to store output files.
#   --seed-for-loads TEXT     Input seed to ensure reproducibility of loads
#                             generation
#   --seed-for-res TEXT       Input seed to ensure reproducibility of renewables
#                             generation
#   --seed-for-dispatch TEXT  Input seed to ensure reproducibility of dispatch
#   --ignore-warnings         Ignore the warnings related to the existence of
#                             data files in the chosen output directory.
#   --scenario_name TEXT      subname to add to the generated scenario output
#                             folder, as Scenario_subname_i
#   --nb_core INTEGER         number of cores to parallelize the number of
#                             scenarios
#   --help                    Show this message and exit.
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\grid2op\Backend\pandaPowerBackend.py:39: UserWarning: Numba cannot be loaded. You will gain possibly massive speed if installing it by
# 	C:\Users\pedro\anaconda3\envs\c2goutravez2\python.exe -m pip install numba
#
#   warnings.warn(

# %%
### CONSTANT

notebook_folder=%pwd

# define your input folder
INPUT_FOLDER = os.path.join(notebook_folder, 'example', 'input')

OUTPUT_FOLDER = os.path.join(notebook_folder, 'example', 'output')

# Detailed configuration to be set in <INPUT_FOLDER>/<CASE>/params.json
start_date = "2012-01-01"
weeks = 8
n_scenarios = 1
by_n_weeks = 4

mode = 'RLTK'


CASE = 'case118_l2rpn_wcci'

# %%
cli_chronix2grid="chronix2grid \
                         --mode {} --output-folder {} --input-folder {} --ignore-warnings \
                         --weeks {} --case {} --n_scenarios {} --start-date {} --by-n-weeks {}".format(
                         mode, OUTPUT_FOLDER, INPUT_FOLDER, weeks, CASE, n_scenarios, start_date,by_n_weeks)
cli_chronix2grid
# Out:
# 'chronix2grid                          --mode RLTK --output-folder c:\\Users\\pedro\\git_clone_c2g\\chronix2grid\\getting_started\\example\\output --input-folder c:\\Users\\pedro\\git_clone_c2g\\chronix2grid\\getting_started\\example\\input --ignore-warnings                          --weeks 8 --case case118_l2rpn_wcci --n_scenarios 1 --start-date 2012-01-01 --by-n-weeks 4'

# %%
# !$cli_chronix2grid
# Out:
# case118_l2rpn_wcci
# initial_seeds
# {'loads': 1195884441, 'renewables': 1195884441, 'dispatch': 1195884441}
# seeds for scenario: Scenario_0
# {'loads': 1195884441, 'renewables': 1195884441, 'dispatch': 1195884441}
# scenario_path: c:\Users\pedro\git_clone_c2g\chronix2grid\getting_started\example\output\generation\case118_l2rpn_wcci\2012-01-01\Scenario_0
# =====================================================================================================================================
# ============================================== CHRONICS GENERATION ==================================================================
# =====================================================================================================================================
# ================ Generating Scenario_0 ================
# Computing global auto-correlated spatio-temporal noise for thermosensible demand...
# Computing loads ...
# Saving files in zipped csv in "c:\Users\pedro\git_clone_c2g\chronix2grid\getting_started\example\output\generation\case118_l2rpn_wcci\2012-01-01\Scenario_0"
# Computing global auto-correlated spatio-temporal noise for sun and wind...
# Generating solar and wind production chronics
# Saving files in zipped csv
# mode_opf is not None
# Preprocessing input data..
# Filter generators ramps up/down
# Adapting PyPSA grid with parameters..
# mode_opf is not None: month
#
# --> OPF formulation by => month - Analyzing month # 1
# Running HiGHS 1.10.0 (git hash: fd86653): Copyright (c) 2025 HiGHS under MIT licence terms
# ERROR:   getOptionIndex: Option "pyomo" is unknown
# LP   linopy-problem-jz1962gd has 1187360 rows; 303552 cols; 2053312 nonzeros
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e-01, 5e+01]
#   Bound  [0e+00, 0e+00]
#   RHS    [1e+00, 4e+03]
# Presolving model
# 580256 rows, 285696 cols, 1428352 nonzeros  0s
# 294592 rows, 285696 cols, 857024 nonzeros  1s
# Dependent equations search running on 8928 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.01s (limit = 1000.00s)
# 294592 rows, 285696 cols, 857024 nonzeros  2s
# Presolve : Reductions: rows 294592(-892768); columns 285696(-17856); elements 857024(-1196288)
# Solving the presolved LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 8928(2.85096e+07) 3s
#       69537     1.0203586925e+09 Pr: 10844(99005.5); Du: 0(1.85618e-07) 8s
#       87545     1.0203523015e+09 Pr: 0(0) 11s
# Solving the original LP from the solution after postsolve
# Model name          : linopy-problem-jz1962gd
# Model status        : Optimal
# Simplex   iterations: 87545
# Objective value     :  1.0203523015e+09
# Relative P-D gap    :  2.4300951927e-14
# HiGHS run time      :         11.31
# Writing the solution to C:\Users\pedro\AppData\Local\Temp\linopy-solve-roqya5a1.sol
# -- opf succeeded  >Objective value (should be greater than zero!
#
# --> OPF formulation by => month - Analyzing month # 2
# Running HiGHS 1.10.0 (git hash: fd86653): Copyright (c) 2025 HiGHS under MIT licence terms
# ERROR:   getOptionIndex: Option "pyomo" is unknown
# LP   linopy-problem-vi4yg4y4 has 957403 rows; 244766 cols; 1655642 nonzeros
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e-01, 5e+01]
#   Bound  [0e+00, 0e+00]
#   RHS    [1e+00, 4e+03]
# Presolving model
# 467871 rows, 230368 cols, 1151712 nonzeros  0s
# 237535 rows, 230368 cols, 691040 nonzeros  1s
# Dependent equations search running on 7199 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.01s (limit = 1000.00s)
# 237535 rows, 230368 cols, 691040 nonzeros  1s
# Presolve : Reductions: rows 237535(-719868); columns 230368(-14398); elements 691040(-964602)
# Solving the presolved LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 7199(2.31052e+07) 2s
#       57796     8.1830999851e+08 Pr: 0(0) 7s
# Solving the original LP from the solution after postsolve
# Model name          : linopy-problem-vi4yg4y4
# Model status        : Optimal
# Simplex   iterations: 57796
# Objective value     :  8.1830999851e+08
# Relative P-D gap    :  7.2401677867e-14
# HiGHS run time      :          7.43
# Writing the solution to C:\Users\pedro\AppData\Local\Temp\linopy-solve-2elb2qj0.sol
# -- opf succeeded  >Objective value (should be greater than zero!
# Total time 1.04 min
# OPF Done......
# Saving results for the grids with individual generators...
# INFO: wind curtailment max: 0.00MW
# INFO: wind curtailment min: 0.00MW
# INFO: wind curtailment sum: 0.00MWh (total 394100.07MWh: 0.00%)
# INFO: solar curtailment max: 0.00MW
# INFO: solar curtailment min: 0.00MW
# INFO: solar curtailment sum: 0.00MWh (total 0.00MWh: 0.00%)
# applying noise to forecast of 0.01 %
# temporary copy of grid in c:\Users\pedro\git_clone_c2g\chronix2grid\getting_started\example\input\generation\case118_l2rpn_wcci_Scenario_0
# temporary copy of chronics in c:\Users\pedro\git_clone_c2g\chronix2grid\getting_started\example\input\generation\case118_l2rpn_wcci_Scenario_0\chronics\Scenario_0
# Start grid2op simulation to compute realistic loss on grid
# Grid2op simulation for loss
# ---- end of simulation
# Start realistic loss correction from simulation results
# maximum compensation for slack before correction in MW: 71.70671844482422
# average compensation for slack before correction in MW: 29.002775012418596
# median compensation for slack before correction in MW: 28.703016662597662
# min compensation for slack before correction in MW: 11.163085556030273
# Warning - Loss correction violates generator constraints: Ramp up + margin is violated with maximum of 20.997812271118164 MW -
# ---- end of loss correction
#
#
# WARNING: make sure that your generated data is in folder: c:\Users\pedro\git_clone_c2g\chronix2grid\getting_started\example\output\generation\case118_l2rpn_wcci\2012-01-01
# =====================================================================================================================================
# ================================================= KPI GENERATION  ===================================================================
# =====================================================================================================================================
# Scenario_0...
# Warning: KPI are incomplete. Computation has been made on 8 weeks, but are meant to be computed on 52 weeks
# Importing and formatting data downloaded from regional eco2mix data
# Importing and formatting synthetic chronics
# (1) Computing KPI's...
# Warning: prices data have not been given for both synthetic and reference dispatch. Quantiles will be computed on demand instead. Next time, you can provide .../France/eco2mix/prices_2012.csv.bz2
#
# (2) Generating json output file...
# -Done-
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\grid2op\Backend\pandaPowerBackend.py:39: UserWarning: Numba cannot be loaded. You will gain possibly massive speed if installing it by
# 	C:\Users\pedro\anaconda3\envs\c2goutravez2\python.exe -m pip install numba
#
#   warnings.warn(
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\chronix2grid\generation\renewable\generate_solar_wind.py:225: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\chronix2grid\generation\dispatch\EconomicDispatch.py:197: FutureWarning:
#
# The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\chronix2grid\generation\dispatch\EconomicDispatch.py:238: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\chronix2grid\generation\dispatch\EconomicDispatch.py:239: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\chronix2grid\generation\_dispatch\_PypsaDispatchBackend\_EDispatch_L2RPN2020\utils.py:181: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.model:Solver options:
#  - pyomo: False
# INFO:linopy.io:Writing objective.
#
# Writing constraints.:   0%|          | 0/5 [00:00<?, ?it/s]
# Writing constraints.:  20%|##        | 1/5 [00:01<00:04,  1.11s/it]
# Writing constraints.:  40%|####      | 2/5 [00:02<00:03,  1.15s/it]
# Writing constraints.:  60%|######    | 3/5 [00:04<00:03,  1.52s/it]
# Writing constraints.:  80%|########  | 4/5 [00:06<00:01,  1.66s/it]
# Writing constraints.: 100%|##########| 5/5 [00:06<00:00,  1.34s/it]
# Writing constraints.: 100%|##########| 5/5 [00:06<00:00,  1.38s/it]
#
# Writing continuous variables.:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing continuous variables.: 100%|##########| 1/1 [00:00<00:00,  1.37it/s]
# Writing continuous variables.: 100%|##########| 1/1 [00:00<00:00,  1.37it/s]
# INFO:linopy.io: Writing time: 8.22s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 303552 primals, 1187360 duals
# Objective: 1.02e+09
# Solver model: available
# Solver message: Optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-fix-p-ramp_limit_up, Generator-fix-p-ramp_limit_down were not assigned to the network.
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.model:Solver options:
#  - pyomo: False
# INFO:linopy.io:Writing objective.
#
# Writing constraints.:   0%|          | 0/5 [00:00<?, ?it/s]
# Writing constraints.:  20%|##        | 1/5 [00:00<00:03,  1.11it/s]
# Writing constraints.:  40%|####      | 2/5 [00:01<00:02,  1.00it/s]
# Writing constraints.:  60%|######    | 3/5 [00:03<00:02,  1.22s/it]
# Writing constraints.:  80%|########  | 4/5 [00:04<00:01,  1.32s/it]
# Writing constraints.: 100%|##########| 5/5 [00:05<00:00,  1.08s/it]
# Writing constraints.: 100%|##########| 5/5 [00:05<00:00,  1.11s/it]
#
# Writing continuous variables.:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing continuous variables.: 100%|##########| 1/1 [00:00<00:00,  1.76it/s]
# Writing continuous variables.: 100%|##########| 1/1 [00:00<00:00,  1.76it/s]
# INFO:linopy.io: Writing time: 6.62s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 244766 primals, 957403 duals
# Objective: 8.18e+08
# Solver model: available
# Solver message: Optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-fix-p-ramp_limit_up, Generator-fix-p-ramp_limit_down were not assigned to the network.
# INFO:pandapower.convert_format:These dtypes could not be corrected: {'trafo': ['tap_neutral', 'tap_min', 'tap_max', 'tap_pos']}
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:38: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_neutral"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:46: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_step_percent"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:51: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_pos"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:79: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_step_degree"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_slack.py:114: UserWarning:
#
# We found either some slack coefficient to be < 0. or they were all 0.We set them all to 1.0 to avoid such issues
#
# INFO:pandapower.convert_format:These dtypes could not be corrected: {'trafo': ['tap_neutral', 'tap_min', 'tap_max', 'tap_pos']}
#
# episode:   0%|          | 0/16126 [00:00<?, ?it/s]
# episode:   0%|          | 32/16126 [00:00<00:50, 315.91it/s]
# episode:   0%|          | 64/16126 [00:00<00:52, 305.64it/s]
# episode:   1%|          | 96/16126 [00:00<00:52, 307.98it/s]
# episode:  94%|#########4| 15210/16126 [00:56<00:03, 252.83it/s]
# episode:  94%|#########4| 15239/16126 [00:56<00:03, 261.61it/s]
# episode:  95%|#########4| 15266/16126 [00:56<00:03, 252.12it/s]
# episode:  95%|#########4| 15292/16126 [00:56<00:03, 251.87it/s]
# episode:  95%|#########4| 15318/16126 [00:56<00:03, 252.48it/s]
# episode:  95%|#########5| 15344/16126 [00:56<00:03, 245.13it/s]
# episode:  95%|#########5| 15372/16126 [00:56<00:02, 253.69it/s]
# episode:  95%|#########5| 15398/16126 [00:56<00:03, 238.68it/s]
# episode:  96%|#########5| 15423/16126 [00:56<00:03, 233.47it/s]
# episode:  96%|#########5| 15447/16126 [00:57<00:02, 234.95it/s]
# episode:  96%|#########5| 15473/16126 [00:57<00:02, 241.22it/s]
# episode:  96%|#########6| 15498/16126 [00:57<00:02, 240.46it/s]
# episode:  96%|#########6| 15525/16126 [00:57<00:02, 246.91it/s]
# episode:  96%|#########6| 15551/16126 [00:57<00:02, 249.03it/s]
# episode:  97%|#########6| 15576/16126 [00:57<00:02, 246.89it/s]
# episode:  97%|#########6| 15604/16126 [00:57<00:02, 255.70it/s]
# episode:  97%|#########6| 15630/16126 [00:57<00:01, 248.90it/s]
# episode:  97%|#########7| 15658/16126 [00:57<00:01, 254.59it/s]
# episode:  97%|#########7| 15684/16126 [00:58<00:01, 241.21it/s]
# episode:  97%|#########7| 15714/16126 [00:58<00:01, 255.06it/s]
# episode:  98%|#########7| 15740/16126 [00:58<00:01, 250.86it/s]
# episode:  98%|#########7| 15766/16126 [00:58<00:01, 250.09it/s]
# episode:  98%|#########7| 15792/16126 [00:58<00:01, 242.31it/s]
# episode:  98%|#########8| 15817/16126 [00:58<00:01, 230.25it/s]
# episode:  98%|#########8| 15845/16126 [00:58<00:01, 242.64it/s]
# episode:  98%|#########8| 15872/16126 [00:58<00:01, 249.86it/s]
# episode:  99%|#########8| 15899/16126 [00:58<00:00, 254.91it/s]
# episode:  99%|#########8| 15926/16126 [00:58<00:00, 256.72it/s]
# episode:  99%|#########8| 15954/16126 [00:59<00:00, 262.59it/s]
# episode:  99%|#########9| 15982/16126 [00:59<00:00, 266.30it/s]
# episode:  99%|#########9| 16011/16126 [00:59<00:00, 272.03it/s]
# episode:  99%|#########9| 16039/16126 [00:59<00:00, 272.56it/s]
# episode: 100%|#########9| 16068/16126 [00:59<00:00, 275.51it/s]
# episode: 100%|#########9| 16096/16126 [00:59<00:00, 250.37it/s]
# episode: 100%|##########| 16126/16126 [00:59<00:00, 270.05it/s]
# INFO:grid2op.Environment.baseEnv.grid2op_Runner:Env: 51.45s
# 	 - apply act 10.75s
# 	 - run pf: 5.81s
# 	 - env update + observation: 34.89s
# Agent: 0.78s
# Total time: 59.72s
# Cumulative reward: 789562.687500
# C:\Users\pedro\anaconda3\envs\c2goutravez2\lib\site-packages\chronix2grid\generation\dispatch\dispatch_loss_utils.py:203: UserWarning:
#
# Loss correction violates generator constraints: Ramp up + margin is violated with maximum of 20.997812271118164 MW -
#
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
